# %%
import model as m
import utils

# %%
utils.clf_fit_predict(m.log_clf)[:10]
# Out:
#                         accuracy
# implementation          0.732781
# math                    0.765306
# greedy                  0.777423
# dp                      0.785714
# bruteforce              0.846301
# constructivealgorithms  0.848214
# datastructures          0.858418
# binarysearch             0.90051
# sortings                0.905612
# graphs                  0.912628

# %%
utils.clf_fit_predict(m.lin_clf)[:10]
# 전체 기준으로 그래프인지아닌지.
# Out:
#                         accuracy
# implementation          0.732143
# math                    0.762117
# greedy                  0.776786
# dp                      0.781888
# bruteforce              0.846939
# constructivealgorithms  0.848852
# datastructures          0.853316
# binarysearch            0.899235
# sortings                0.904974
# graphs                  0.910077

# %%
utils.clf_fit_predict(m.nb_clf)[:10]
# Out:
#                         accuracy
# implementation          0.716837
# math                    0.742347
# greedy                  0.764031
# dp                      0.783801
# datastructures           0.83801
# bruteforce              0.846939
# constructivealgorithms  0.848852
# graphs                  0.896684
# binarysearch            0.899235
# sortings                0.904974

# %%
# utils.model_fit_predict(m.kmeans_clf)[:10]

# %%
# %%timeit
# utils.model_fit_predict(m.xgb_clf)[:10]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /home/jhojin/CODE/codeforces_tag_predict/viz.ipynb Cell 6 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu/home/jhojin/CODE/codeforces_tag_predict/viz.ipynb#W5sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> get_ipython().run_cell_magic('timeit', '', '# utils.model_fit_predict(m.xgb_clf)[:10]\n')
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2358, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2356 with self.builtin_trap:
#    2357     args = (magic_arg_s, cell)
# -> 2358     result = fn(*args, **kwargs)
#    2359 return result
#
# File ~/.local/lib/python3.8/site-packages/IPython/core/magics/execution.py:1139, in ExecutionMagics.timeit(self, line, cell, local_ns)
#    1136 tc_min = 0.1
#    1138 t0 = clock()
# ...
