# %%
import model as m
import utils

# %%
utils.model_fit_predict(m.logistic)[:10]
# Out:
#                         accuracy
# implementation          0.732781
# math                    0.765306
# greedy                  0.777423
# dp                      0.785714
# bruteforce              0.846301
# constructivealgorithms  0.848214
# datastructures          0.858418
# binarysearch             0.90051
# sortings                0.905612
# graphs                  0.912628

# %%
utils.model_fit_predict(m.lin_clf)[:10]
# Out:
#                         accuracy
# implementation          0.732143
# math                    0.762117
# greedy                  0.776786
# dp                      0.781888
# bruteforce              0.846939
# constructivealgorithms  0.848852
# datastructures          0.853316
# binarysearch            0.899235
# sortings                0.904974
# graphs                  0.910077

# %%
# %%timeit
utils.model_fit_predict(m.xgb_clf)[:10]
# Out:
# 2min 17s ± 30.9 s per loop (mean ± std. dev. of 7 runs, 1 loop each)
